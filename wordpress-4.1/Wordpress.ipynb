# %% [markdown]
# ## Install Wordpress

# %%
from guide_automator_function import *

get("localhost:8080/")

click('#language-continue')
takeScreenshot()
fillIn('#weblog_title', 'Ubuntu Blog Wordpress')
fillIn('#user_login', 'Admin')
fillIn('#pass1', 'Admin')
fillIn('#pass2', 'Admin')
fillIn('#admin_email', 'guidovalle1608@gmail.com')
click('.button')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F0D340D6EF0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F0D340D6668>
