# %% [markdown]
# ## How to install Wordpress

# %%
from guide_automator_function import *

get("localhost:8080/")
highlight('#language-continue')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F9F6CEA21D0>

# %% [markdown]
# ## Select your language, and click on the continue button

# %%
click('#language-continue')
fillIn('#weblog_title', 'Ubuntu Blog Wordpress')
fillIn('#user_login', 'Admin')
fillIn('#pass1', 'Admin')
fillIn('#pass2', 'Admin')
fillIn('#admin_email', 'guidovalle1608@gmail.com')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F9F6CC1FFD0>

# %% [markdown]
# ## Fill in the fields

# %%
click('.button')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F9F6CC2FA20>

# %%
## Congratulations, you have installed Wordpress!
